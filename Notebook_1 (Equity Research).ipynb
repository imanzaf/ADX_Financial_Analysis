# %% [markdown]
# ## Equity Research - Visualisations

# %% [markdown]
# ### Data & Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import chart_studio.plotly as py
# %matplotlib inline
import cufflinks as cf

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)

cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
# ...

# %%
#keep plotly figures persistent between sessions
import plotly.io as pio
pio.renderers.default = "svg"

# %%
KEY20 = pd.read_excel('data/Key Figures.xlsx', sheet_name='2020')

# %%
RAT20 = pd.read_excel('data/Key Figures.xlsx', sheet_name='Sheet3')

# %%
KEY21 = pd.read_excel('data/Key Figures.xlsx', sheet_name='2021')

# %%
RAT21 = pd.read_excel('data/Key Figures.xlsx', sheet_name='2021.2')

# %% [markdown]
# ### Balance Sheet Figures

# %%
cf.getThemes()
# Out:
# ['ggplot', 'pearl', 'solar', 'space', 'white', 'polar', 'henanigans']

# %%
KEY20.iplot(kind='bar', x='Company', y=['Revenue', 'Total Assets','Market Cap'], theme='ggplot', colorscale='dflt', 
           annotations={'ADH': '5.39B', 'IHC': '14.01B', 'Etisalat':'133.02B', 'FAB':'919.06B', 'TAQA':'186.93B'})

# %%
KEY21.iplot(kind='bar', x='Company', y=['Revenue', 'Total Assets','Market Cap'], theme='ggplot', colorscale='dflt',
           annotations={'ADH': '34.26B', 'IHC': '58.32B', 'Etisalat':'125.23B', 'FAB':'943.64B', 'TAQA':'186.93B'})

# %% [markdown]
# ### Financial Ratios

# %%
sns.set_style('darkgrid')

# %%
plt.figure(figsize=(17,4))

plt.subplot(1, 3, 1)
plt.bar('Company', 'P/E', data=RAT20, color='grey')
plt.title('P/E', fontdict={'fontsize': 14})

plt.subplot(1, 3, 2)
plt.bar('Company', 'D/E', data=RAT20)
plt.title('D/E', fontdict={'fontsize': 14})

plt.subplot(1, 3, 3)
plt.bar('Company', 'P/B', data=RAT20, color='black')
plt.title('P/B', fontdict={'fontsize': 14});

# %%
plt.figure(figsize=(12,4))

plt.subplot(1, 2, 1)
plt.bar('Company', 'ROSE (%)', data=RAT20, color='lightblue')
plt.title('ROSE (%)', fontdict={'fontsize': 14})

plt.subplot(1, 2, 2)
plt.bar('Company', 'ROCE (%)', data=RAT20, color='darkgrey')
plt.title('ROCE (%)', fontdict={'fontsize': 14});

# %%
plt.figure(figsize=(17,4))

plt.subplot(1, 3, 1)
plt.bar('Company', 'P/E', data=RAT21, color='grey')
plt.title('P/E', fontdict={'fontsize': 14})

plt.subplot(1, 3, 2)
plt.bar('Company', 'D/E', data=RAT21)
plt.title('D/E', fontdict={'fontsize': 14})

plt.subplot(1, 3, 3)
plt.bar('Company', 'P/B', data=RAT21, color='black')
plt.title('P/B', fontdict={'fontsize': 14});

# %%
plt.figure(figsize=(12,4))

plt.subplot(1, 2, 1)
plt.bar('Company', 'ROSE (%)', data=RAT21, color='lightblue')
plt.title('ROSE (%)', fontdict={'fontsize': 14})

plt.subplot(1, 2, 2)
plt.bar('Company', 'ROCE (%)', data=RAT21, color='darkgrey')
plt.title('ROCE (%)', fontdict={'fontsize': 14});

# %%
EMP = pd.read_excel('Key Figures.xlsx', sheet_name='Sheet4')

# %% [markdown]
# ### Company Info

# %%
EMP
# Out:
#     Company  Employee Size
# 0       ADH          40000
# 1       IHC          47000
# 2  ETISALAT          43000
# 3       FAB           5500
# 4      TAQA           7000

# %%
plt.figure(figsize=(20,12))
fig = sns.barplot(x='Company', y='Employee Size', data=EMP, palette='viridis')
fig.tick_params(labelsize=14)
fig.set_xlabel('')
fig.set_ylabel('');
